# %% [markdown]
# ### API Limits
# * Max 100 results per page, default is 20
# * Basic access is granted automatically after collecting a few details and will allow you to make up to 1,000 requests/day, with a rate limit of 50 requests/second. If you need more bandwidth, you can request more once you have your basic key.
# * Access tokens expire in 3600 seconds (1 hour)

# %%
import requests
from config import CLIENTID
from config import CLIENTSECRET
from datetime import datetime
import pandas as pd
import json
from pandas.io.json import json_normalize
import time
import numpy as np

# %% [markdown]
# ### Connecting to PetFinder API

# %%
credentials = {
  'grant_type': 'client_credentials',
  'client_id': {CLIENTID},
  'client_secret': {CLIENTSECRET}
}

token_response = requests.post('https://api.petfinder.com/v2/oauth2/token', data=credentials)
access_token = token_response.json()['access_token']

data_auth = {
    'Authorization': f'Bearer {access_token}',
}

startTime = datetime.now()

# time to check start of access token 
print(startTime)
# Out:
# 2019-10-27 13:00:10.819140

# %%
base_url = "https://api.petfinder.com/v2/types?"

data_response = requests.get(base_url, headers=data_auth)
data_response.json() # this is a dictionary
# Out:
# {'types': [{'name': 'Dog',
#    'coats': ['Hairless', 'Short', 'Medium', 'Long', 'Wire', 'Curly'],
#    'colors': ['Apricot / Beige',
#     'Bicolor',
#     'Black',
#     'Brindle',
#     'Brown / Chocolate',
#     'Golden',
#     'Gray / Blue / Silver',
#     'Harlequin',
#     'Merle (Blue)',
#     'Merle (Red)',
#     'Red / Chestnut / Orange',
#     'Sable',
#     'Tricolor (Brown, Black, & White)',
#     'White / Cream',
#     'Yellow / Tan / Blond / Fawn'],
#    'genders': ['Male', 'Female'],
#    '_links': {'self': {'href': '/v2/types/dog'},
#     'breeds': {'href': '/v2/types/dog/breeds'}}},
#   {'name': 'Cat',
#    'coats': ['Hairless', 'Short', 'Medium', 'Long'],
#    'colors': ['Black',
#     'Black & White / Tuxedo',
#     'Blue Cream',
#     'Blue Point',
#     'Brown / Chocolate',
#     'Buff & White',
#     'Buff / Tan / Fawn',
#     'Calico',
#     'Chocolate Point',
#     'Cream / Ivory',
#     'Cream Point',
#     'Dilute Calico',
#     'Dilute Tortoiseshell',
#     'Flame Point',
#     'Gray & White',
#     'Gray / Blue / Silver',
#     'Lilac Point',
#     'Orange & White',
#     'Orange / Red',
#     'Seal Point',
#     'Smoke',
#     'Tabby (Brown / Chocolate)',
#     'Tabby (Buff / Tan / Fawn)',
#     'Tabby (Gray / Blue / Silver)',
#     'Tabby (Leopard / Spotted)',
#     'Tabby (Orange / Red)',
#     'Tabby (Tiger Striped)',
#     'Torbie',
#     'Tortoiseshell',
#     'White'],
#    'genders': ['Male', 'Female'],
#    '_links': {'self': {'href': '/v2/types/cat'},
#     'breeds': {'href': '/v2/types/cat/breeds'}}},
#   {'name': 'Rabbit',
#    'coats': ['Short', 'Long'],
#    'colors': ['Agouti',
#     'Black',
#     'Blue / Gray',
#     'Brown / Chocolate',
#     'Cream',
#     'Lilac',
#     'Orange / Red',
#     'Sable',
#     'Silver Marten',
#     'Tan',
#     'Tortoiseshell',
#     'White'],
#    'genders': ['Male', 'Female'],
#    '_links': {'self': {'href': '/v2/types/rabbit'},
#     'breeds': {'href': '/v2/types/rabbit/breeds'}}},
#   {'name': 'Small & Furry',
#    'coats': ['Hairless', 'Short', 'Long'],
#    'colors': ['Agouti',
#     'Albino',
#     'Black',
#     'Black Sable',
#     'Blue / Gray',
#     'Brown / Chocolate',
#     'Calico',
#     'Champagne',
#     'Cinnamon',
#     'Cream',
#     'Orange / Red',
#     'Sable',
#     'Tan',
#     'Tortoiseshell',
#     'White',
#     'White (Dark-Eyed)'],
#    'genders': ['Male', 'Female'],
#    '_links': {'self': {'href': '/v2/types/small-furry'},
#     'breeds': {'href': '/v2/types/small-furry/breeds'}}},
#   {'name': 'Horse',
#    'coats': [],
#    'colors': ['Appaloosa',
#     'Bay',
#     'Bay Roan',
#     'Black',
#     'Blue Roan',
#     'Brown',
#     'Buckskin',
#     'Champagne',
#     'Chestnut / Sorrel',
#     'Cremello',
#     'Dapple Gray',
#     'Dun',
#     'Gray',
#     'Grullo',
#     'Liver',
#     'Paint',
#     'Palomino',
#     'Perlino',
#     'Piebald',
#     'Pinto',
#     'Red Roan',
#     'Silver Bay',
#     'Silver Buckskin',
#     'Silver Dapple',
#     'White'],
#    'genders': ['Male', 'Female'],
#    '_links': {'self': {'href': '/v2/types/horse'},
#     'breeds': {'href': '/v2/types/horse/breeds'}}},
#   {'name': 'Bird',
#    'coats': [],
#    'colors': ['Black',
#     'Blue',
#     'Brown',
#     'Buff',
#     'Gray',
#     'Green',
#     'Olive',
#     'Orange',
#     'Pink',
#     'Purple / Violet',
#     'Red',
#     'Rust / Rufous',
#     'Tan',
#     'White',
#     'Yellow'],
#    'genders': ['Male', 'Female', 'Unknown'],
#    '_links': {'self': {'href': '/v2/types/bird'},
#     'breeds': {'href': '/v2/types/bird/breeds'}}},
#   {'name': 'Scales, Fins & Other',
#    'coats': [],
#    'colors': ['Black',
#     'Blue',
#     'Brown',
#     'Gray',
#     'Green',
#     'Iridescent',
#     'Orange',
#     'Purple',
#     'Red',
#     'Tan',
#     'White',
#     'Yellow'],
#    'genders': ['Male', 'Female', 'Unknown'],
#    '_links': {'self': {'href': '/v2/types/scales-fins-other'},
#     'breeds': {'href': '/v2/types/scales-fins-other/breeds'}}},
#   {'name': 'Barnyard',
#    'coats': ['Short', 'Long'],
#    'colors': ['Agouti',
#     'Black',
#     'Black & White',
#     'Brindle',
#     'Brown',
#     'Gray',
#     'Pink',
#     'Red',
#     'Roan',
#     'Spotted',
#     'Tan',
#     'White'],
#    'genders': ['Male', 'Female'],
#    '_links': {'self': {'href': '/v2/types/barnyard'},
#     'breeds': {'href': '/v2/types/barnyard/breeds'}}}]}

# %% [markdown]
# ## PetFinder API Dog Breeds

# %%
dogbreed_url = "https://api.petfinder.com/v2/types/dog/breeds?"
dog_response = requests.get(dogbreed_url, headers=data_auth)
dogbreed_dict = dog_response.json()
dogbreed_dict
# Out:
# {'breeds': [{'name': 'Affenpinscher',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Afghan Hound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Airedale Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Akbash', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Akita', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Alaskan Malamute', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'American Bulldog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'American Eskimo Dog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'American Foxhound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'American Hairless Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'American Staffordshire Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'American Water Spaniel',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Anatolian Shepherd',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Appenzell Mountain Dog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Australian Cattle Dog / Blue Heeler',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Australian Kelpie', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Australian Shepherd',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Australian Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Basenji', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Basset Hound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Beagle', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Bearded Collie', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Beauceron', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Bedlington Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Belgian Shepherd / Laekenois',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Belgian Shepherd / Malinois',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Belgian Shepherd / Sheepdog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Belgian Shepherd / Tervuren',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Bernese Mountain Dog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Bichon Frise', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Black and Tan Coonhound',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Black Labrador Retriever',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Black Mouth Cur', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Black Russian Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Bloodhound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Blue Lacy', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Bluetick Coonhound',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Boerboel', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Bolognese', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Border Collie', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Border Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Borzoi', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Boston Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Bouvier des Flandres',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Boxer', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Boykin Spaniel', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Briard', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Brittany Spaniel', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Brussels Griffon', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Bull Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Bullmastiff', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Cairn Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Canaan Dog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Cane Corso', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Cardigan Welsh Corgi',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Carolina Dog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Catahoula Leopard Dog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Cattle Dog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Caucasian Sheepdog / Caucasian Ovtcharka',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Cavalier King Charles Spaniel',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Chesapeake Bay Retriever',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Chihuahua', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Chinese Crested Dog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Chinese Foo Dog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Chinook', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Chocolate Labrador Retriever',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Chow Chow', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': "Cirneco dell'Etna", '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Clumber Spaniel', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Cockapoo', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Cocker Spaniel', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Collie', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Coonhound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Corgi', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Coton de Tulear', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Curly-Coated Retriever',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Dachshund', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Dalmatian', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Dandie Dinmont Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Doberman Pinscher', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Dogo Argentino', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Dogue de Bordeaux', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Dutch Shepherd', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'English Bulldog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'English Cocker Spaniel',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'English Coonhound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'English Foxhound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'English Pointer', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'English Setter', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'English Shepherd', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'English Springer Spaniel',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'English Toy Spaniel',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Entlebucher', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Eskimo Dog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Feist', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Field Spaniel', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Fila Brasileiro', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Finnish Lapphund', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Finnish Spitz', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Flat-Coated Retriever',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Fox Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Foxhound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'French Bulldog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Galgo Spanish Greyhound',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'German Pinscher', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'German Shepherd Dog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'German Shorthaired Pointer',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'German Spitz', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'German Wirehaired Pointer',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Giant Schnauzer', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Glen of Imaal Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Golden Retriever', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Gordon Setter', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Great Dane', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Great Pyrenees', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Greater Swiss Mountain Dog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Greyhound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Hamiltonstovare', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Harrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Havanese', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Hound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Hovawart', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Husky', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Ibizan Hound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Icelandic Sheepdog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Illyrian Sheepdog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Irish Setter', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Irish Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Irish Water Spaniel',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Irish Wolfhound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Italian Greyhound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Jack Russell Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Japanese Chin', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Jindo', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Kai Dog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Karelian Bear Dog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Keeshond', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Kerry Blue Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Kishu', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Klee Kai', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Komondor', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Kuvasz', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Kyi Leo', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Labrador Retriever',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Lakeland Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Lancashire Heeler', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Leonberger', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Lhasa Apso', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Lowchen', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Maltese', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Manchester Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Maremma Sheepdog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Mastiff', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'McNab', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Miniature Bull Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Miniature Dachshund',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Miniature Pinscher',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Miniature Poodle', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Miniature Schnauzer',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Mixed Breed', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Mountain Cur', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Mountain Dog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Munsterlander', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Neapolitan Mastiff',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'New Guinea Singing Dog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Newfoundland Dog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Norfolk Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Norwegian Buhund', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Norwegian Elkhound',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Norwegian Lundehund',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Norwich Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Nova Scotia Duck Tolling Retriever',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Old English Sheepdog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Otterhound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Papillon', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Parson Russell Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Patterdale Terrier / Fell Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Pekingese', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Pembroke Welsh Corgi',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Peruvian Inca Orchid',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Petit Basset Griffon Vendeen',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Pharaoh Hound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Pit Bull Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Plott Hound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Pointer', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Polish Lowland Sheepdog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Pomeranian', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Poodle', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Portuguese Podengo',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Portuguese Water Dog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Presa Canario', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Pug', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Puli', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Pumi', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Pyrenean Shepherd', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Rat Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Redbone Coonhound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Retriever', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Rhodesian Ridgeback',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Rottweiler', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Rough Collie', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Saint Bernard', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Saluki', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Samoyed', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Sarplaninac', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Schipperke', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Schnauzer', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Scottish Deerhound',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Scottish Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Sealyham Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Setter', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Shar-Pei', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Sheep Dog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Shepherd', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Shetland Sheepdog / Sheltie',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Shiba Inu', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Shih Tzu', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Siberian Husky', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Silky Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Skye Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Sloughi', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Smooth Collie', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Smooth Fox Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'South Russian Ovtcharka',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Spaniel', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Spanish Water Dog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Spinone Italiano', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Spitz', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Staffordshire Bull Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Standard Poodle', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Standard Schnauzer',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Sussex Spaniel', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Swedish Vallhund', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Thai Ridgeback', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Tibetan Mastiff', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Tibetan Spaniel', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Tibetan Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Tosa Inu', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Toy Fox Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Toy Manchester Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Treeing Walker Coonhound',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Vizsla', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Weimaraner', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Welsh Springer Spaniel',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Welsh Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'West Highland White Terrier / Westie',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Wheaten Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Whippet', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'White German Shepherd',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Wire Fox Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Wirehaired Dachshund',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Wirehaired Pointing Griffon',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Wirehaired Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Xoloitzcuintli / Mexican Hairless',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Yellow Labrador Retriever',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Yorkshire Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}}]}

# %%
dogbreed_df = pd.DataFrame.from_dict(dogbreed_dict, orient='columns')
dogbreed_df2 = dogbreed_df['breeds']

secondtry = {k:v for k,v in dogbreed_df2.items()}

PetFinder_DogBreeds = []
for item in dogbreed_df2:
    PetFinder_DogBreeds.append(item["name"])

# %%
PetFinder_DogBreeds[:20]
# Out:
# ['Affenpinscher',
#  'Afghan Hound',
#  'Airedale Terrier',
#  'Akbash',
#  'Akita',
#  'Alaskan Malamute',
#  'American Bulldog',
#  'American Eskimo Dog',
#  'American Foxhound',
#  'American Hairless Terrier',
#  'American Staffordshire Terrier',
#  'American Water Spaniel',
#  'Anatolian Shepherd',
#  'Appenzell Mountain Dog',
#  'Australian Cattle Dog / Blue Heeler',
#  'Australian Kelpie',
#  'Australian Shepherd',
#  'Australian Terrier',
#  'Basenji',
#  'Basset Hound']

# %%
top_breeds_df = pd.read_excel('web_scraping/top_breeds_excel.xlsx', index_col=0)
top_breeds_df.head(20)
# Out:
#                              Breed  Rank
# 1            Retrievers (Labrador)     1
# 2             German Shepherd Dogs     2
# 3              Retrievers (Golden)     3
# 4                  French Bulldogs     4
# 5                         Bulldogs     5
# 6                          Beagles     6
# 7                          Poodles     7
# 8                      Rottweilers     8
# 9    Pointers (German Shorthaired)     9
# 10              Yorkshire Terriers    10
# 11                          Boxers    11
# 12                      Dachshunds    12
# 13           Pembroke Welsh Corgis    13
# 14                Siberian Huskies    14
# 15            Australian Shepherds    15
# 16                     Great Danes    16
# 17              Doberman Pinschers    17
# 18  Cavalier King Charles Spaniels    18
# 19            Miniature Schnauzers    19
# 20                        Shih Tzu    20

# %%
top_breeds_df.replace(u'\xa0',u' ', regex=True, inplace=True)

# %%
top_breeds_df.head(20)
# Out:
#                              Breed  Rank
# 1            Retrievers (Labrador)     1
# 2             German Shepherd Dogs     2
# 3              Retrievers (Golden)     3
# 4                  French Bulldogs     4
# 5                         Bulldogs     5
# 6                          Beagles     6
# 7                          Poodles     7
# 8                      Rottweilers     8
# 9    Pointers (German Shorthaired)     9
# 10              Yorkshire Terriers    10
# 11                          Boxers    11
# 12                      Dachshunds    12
# 13           Pembroke Welsh Corgis    13
# 14                Siberian Huskies    14
# 15            Australian Shepherds    15
# 16                     Great Danes    16
# 17              Doberman Pinschers    17
# 18  Cavalier King Charles Spaniels    18
# 19            Miniature Schnauzers    19
# 20                        Shih Tzu    20

# %%
top_breeds_list = top_breeds_df['Breed'].tolist()

# %%
top_breeds_list[:20]
# Out:
# ['Retrievers (Labrador)',
#  'German Shepherd Dogs',
#  'Retrievers (Golden)',
#  'French Bulldogs',
#  'Bulldogs',
#  'Beagles',
#  'Poodles',
#  'Rottweilers',
#  'Pointers (German Shorthaired)',
#  'Yorkshire Terriers',
#  'Boxers',
#  'Dachshunds',
#  'Pembroke Welsh Corgis',
#  'Siberian Huskies',
#  'Australian Shepherds',
#  'Great Danes',
#  'Doberman Pinschers',
#  'Cavalier King Charles Spaniels',
#  'Miniature Schnauzers',
#  'Shih Tzu']

# %%
singular_top_breeds_list = []
for breed in top_breeds_list:
    if breed.endswith('s'):
        singular_top_breeds_list.append(breed[:-1])
    else:
        singular_top_breeds_list.append(breed)

# %%
singular_top_breeds_list[:20]
# Out:
# ['Retrievers (Labrador)',
#  'German Shepherd Dog',
#  'Retrievers (Golden)',
#  'French Bulldog',
#  'Bulldog',
#  'Beagle',
#  'Poodle',
#  'Rottweiler',
#  'Pointers (German Shorthaired)',
#  'Yorkshire Terrier',
#  'Boxer',
#  'Dachshund',
#  'Pembroke Welsh Corgi',
#  'Siberian Huskie',
#  'Australian Shepherd',
#  'Great Dane',
#  'Doberman Pinscher',
#  'Cavalier King Charles Spaniel',
#  'Miniature Schnauzer',
#  'Shih Tzu']

# %%
singular_top_breeds_df = pd.DataFrame(singular_top_breeds_list)

# %%
singular_top_breeds_df = singular_top_breeds_df.shift()[1:]

# %%
singular_top_breeds_df.head(20)
# Out:
#                                 0
# 1           Retrievers (Labrador)
# 2             German Shepherd Dog
# 3             Retrievers (Golden)
# 4                  French Bulldog
# 5                         Bulldog
# 6                          Beagle
# 7                          Poodle
# 8                      Rottweiler
# 9   Pointers (German Shorthaired)
# 10              Yorkshire Terrier
# 11                          Boxer
# 12                      Dachshund
# 13           Pembroke Welsh Corgi
# 14                Siberian Huskie
# 15            Australian Shepherd
# 16                     Great Dane
# 17              Doberman Pinscher
# 18  Cavalier King Charles Spaniel
# 19            Miniature Schnauzer
# 20                       Shih Tzu

# %%
top_breeds_df['Breed'] = singular_top_breeds_df[0]

# %%
top_breeds_df.head(20)
# Out:
#                             Breed  Rank
# 1           Retrievers (Labrador)     1
# 2             German Shepherd Dog     2
# 3             Retrievers (Golden)     3
# 4                  French Bulldog     4
# 5                         Bulldog     5
# 6                          Beagle     6
# 7                          Poodle     7
# 8                      Rottweiler     8
# 9   Pointers (German Shorthaired)     9
# 10              Yorkshire Terrier    10
# 11                          Boxer    11
# 12                      Dachshund    12
# 13           Pembroke Welsh Corgi    13
# 14                Siberian Huskie    14
# 15            Australian Shepherd    15
# 16                     Great Dane    16
# 17              Doberman Pinscher    17
# 18  Cavalier King Charles Spaniel    18
# 19            Miniature Schnauzer    19
# 20                       Shih Tzu    20

# %%
# top_breeds_verified_on_petfinder[:10]
# Out:
# ['German Shepherd Dog',
#  'French Bulldog',
#  'Beagle',
#  'Poodle',
#  'Rottweiler',
#  'Yorkshire Terrier',
#  'Boxer',
#  'Dachshund',
#  'Pembroke Welsh Corgi',
#  'Australian Shepherd']

# %%
# top_breeds_not_on_petfinder[9:]
# Out:
# ['St. Bernard',
#  'Soft Coated Wheaten Terrier',
#  'Australian Cattle Dog',
#  'Great Pyrenee',
#  'Russell Terrier',
#  'Bouviers des Flandre',
#  'Anatolian Shepherd Dog',
#  'Belgian Sheepdog',
#  'Berger Picard',
#  'Nederlandse Kooikerhondje',
#  'Portuguese Podengo Pequeno',
#  'Petits Bassets Griffons Vendeen',
#  'Entlebucher Mountain Dog',
#  'Wirehaired Vizsla',
#  'Plott',
#  'American English Coonhound',
#  'Grand Basset Griffon Vendeen',
#  'Cesky Terrier',
#  'Bergamasco Sheepdog']

# %%
# for breed in PetFinder_DogBreeds:
#     if breed.startswith('Sheep'):
#         print(breed)
# Out:
# Sheep Dog

# %%
# top_breeds_verified_on_petfinder[:10]
# Out:
# ['German Shepherd Dog',
#  'French Bulldog',
#  'Beagle',
#  'Poodle',
#  'Rottweiler',
#  'Yorkshire Terrier',
#  'Boxer',
#  'Dachshund',
#  'Pembroke Welsh Corgi',
#  'Siberian Husky']

# %%
# top_breeds_not_on_petfinder
# Out:
# ['Bulldog',
#  'Brittany',
#  'Miniature American Shepherd',
#  'Soft Coated Wheaten Terrier',
#  'Russell Terrier',
#  'Berger Picard',
#  'Nederlandse Kooikerhondje',
#  'Portuguese Podengo Pequeno',
#  'Wirehaired Vizsla',
#  'American English Coonhound',
#  'Grand Basset Griffon Vendeen',
#  'Cesky Terrier',
#  'Bergamasco Sheepdog']

# %%
top_breeds_df
# Out:
#                              Breed  Rank
# 1            Retrievers (Labrador)     1
# 2              German Shepherd Dog     2
# 3              Retrievers (Golden)     3
# 4                   French Bulldog     4
# 5                          Bulldog     5
# 6                           Beagle     6
# 7                           Poodle     7
# 8                       Rottweiler     8
# 9    Pointers (German Shorthaired)     9
# 10               Yorkshire Terrier    10
# 11                           Boxer    11
# 12                       Dachshund    12
# 13            Pembroke Welsh Corgi    13
# 14                 Siberian Huskie    14
# 15             Australian Shepherd    15
# 16                      Great Dane    16
# 17               Doberman Pinscher    17
# 18   Cavalier King Charles Spaniel    18
# 19             Miniature Schnauzer    19
# 20                        Shih Tzu    20
# 21                  Boston Terrier    21
# 22            Bernese Mountain Dog    22
# 23                      Pomeranian    23
# 24                        Havanese    24
# 25               Shetland Sheepdog    25
# 26                        Brittany    26
# 27     Spaniels (English Springer)    27
# 28                             Pug    28
# 29                         Mastiff    29
# 30               Spaniels (Cocker)    30
# ..                             ...   ...
# 163                       Kuvaszok   163
# 164               Sealyham Terrier   164
# 165               Norwegian Buhund   165
# 166      Spaniels (American Water)   166
# 167              Wirehaired Vizsla   167
# 168                        Lowchen   168
# 169               Swedish Vallhund   169
# 170        Polish Lowland Sheepdog   170
# 171                          Plott   171
# 172                  Pharaoh Hound   172
# 173                     Komondorok   173
# 174          Glen of Imaal Terrier   174
# 175     American English Coonhound   175
# 176         Dandie Dinmont Terrier   176
# 177   Grand Basset Griffon Vendeen   177
# 178                   Skye Terrier   178
# 179                     Canaan Dog   179
# 180              Spaniels (Sussex)   180
# 181              Pyrenean Shepherd   181
# 182                     Otterhound   182
# 183             Cirnechi dell’Etna   183
# 184                  Finnish Spitz   184
# 185                  Cesky Terrier   185
# 186              American Foxhound   186
# 187            Bergamasco Sheepdog   187
# 188               English Foxhound   188
# 189                        Harrier   189
# 190                        Chinook   190
# 191            Norwegian Lundehund   191
# 192                            NaN   192
#
# [192 rows x 2 columns]

# %%
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Siberian Huskie"], "Siberian Husky")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Shetland Sheepdog"], "Shetland Sheepdog / Sheltie")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Newfoundland"], "Newfoundland Dog")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["West Highland White Terrier"], "West Highland White Terrier / Westie")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Belgian Malinoi"], "Belgian Shepherd / Malinois")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Bichons Frise"], "Bichon Frise")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["St. Bernard"], "Saint Bernard")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Australian Cattle Dog"], "Australian Cattle Dog / Blue Heeler")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Great Pyrenee"], "Great Pyrenees")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Bouviers des Flandre"], "Bouvier des Flandres")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Anatolian Shepherd Dog"], "Anatolian Shepherd")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Belgian Sheepdog"], "Belgian Shepherd / Sheepdog")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Petits Bassets Griffons Vendeen"], "Petit Basset Griffon Vendeen")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Entlebucher Mountain Dog"], "Entlebucher")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Plott"], "Plott Hound")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Retrievers (Labrador)"], "Labrador Retriever")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Retrievers (Golden)"], "Golden Retriever")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Pointers (German Shorthaired)"], "German Shorthaired Pointer")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Spaniels (English Springer)"], "English Springer Spaniel")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Spaniels (Cocker)"], "Cocker Spaniel")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Retrievers (Chesapeake Bay)"], "Chesapeake Bay Retriever")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Spaniels (English Cocker)"], "English Cocker Spaniel")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Pointers (German Wirehaired)"], "German Wirehaired Pointer")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Setters (Irish)"], "Irish Setter")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Chinese Crested"], "Chinese Crested Dog")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Retrievers (Nova Scotia Duck Tolling)"], "Nova Scotia Duck Tolling Retriever")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Retrievers (Flat-Coated)"], "Flat-Coated Retriever")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Setters (English)"], "English Setter")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Keeshonden"], "Keeshond")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Spaniels (Boykin)"], "Boykin Spaniel")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Fox Terriers (Wire)"], "Wire Fox Terrier")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Belgian Tervuren"], "Belgian Shepherd / Tervuren")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Spinoni Italiani"], "Spinone Italiano")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Setters (Gordon)"], "Gordon Setter")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Fox Terriers (Smooth)"], "Smooth Fox Terrier")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Spaniels (Welsh Springer)"], "Welsh Springer Spaniel")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Xoloitzcuintli"], "Xoloitzcuintli / Mexican Hairless")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Spaniels (Clumber)"], "Clumber Spaniel")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Spaniels (Field)"], "Field Spaniel")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Pumik"], "Pumi")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Spaniels (Irish Water)"], "Irish Water Spaniel")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Pulik"], "Puli")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Retrievers (Curly-Coated)"], "Curly-Coated Retriever")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Kuvaszok"], "Kuvasz")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Komondorok"], "Komondor")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Spaniels (Sussex)"], "Sussex Spaniel")
top_breeds_df['Breed'] = top_breeds_df['Breed'].replace(["Cirnechi dell’Etna"], "Cirneco dell'Etna")

# %%
top_breeds_df
# Out:
#                              Breed  Rank
# 1               Labrador Retriever     1
# 2              German Shepherd Dog     2
# 3                 Golden Retriever     3
# 4                   French Bulldog     4
# 5                          Bulldog     5
# 6                           Beagle     6
# 7                           Poodle     7
# 8                       Rottweiler     8
# 9       German Shorthaired Pointer     9
# 10               Yorkshire Terrier    10
# 11                           Boxer    11
# 12                       Dachshund    12
# 13            Pembroke Welsh Corgi    13
# 14                  Siberian Husky    14
# 15             Australian Shepherd    15
# 16                      Great Dane    16
# 17               Doberman Pinscher    17
# 18   Cavalier King Charles Spaniel    18
# 19             Miniature Schnauzer    19
# 20                        Shih Tzu    20
# 21                  Boston Terrier    21
# 22            Bernese Mountain Dog    22
# 23                      Pomeranian    23
# 24                        Havanese    24
# 25     Shetland Sheepdog / Sheltie    25
# 26                        Brittany    26
# 27        English Springer Spaniel    27
# 28                             Pug    28
# 29                         Mastiff    29
# 30                  Cocker Spaniel    30
# ..                             ...   ...
# 163                         Kuvasz   163
# 164               Sealyham Terrier   164
# 165               Norwegian Buhund   165
# 166      Spaniels (American Water)   166
# 167              Wirehaired Vizsla   167
# 168                        Lowchen   168
# 169               Swedish Vallhund   169
# 170        Polish Lowland Sheepdog   170
# 171                    Plott Hound   171
# 172                  Pharaoh Hound   172
# 173                       Komondor   173
# 174          Glen of Imaal Terrier   174
# 175     American English Coonhound   175
# 176         Dandie Dinmont Terrier   176
# 177   Grand Basset Griffon Vendeen   177
# 178                   Skye Terrier   178
# 179                     Canaan Dog   179
# 180                 Sussex Spaniel   180
# 181              Pyrenean Shepherd   181
# 182                     Otterhound   182
# 183              Cirneco dell'Etna   183
# 184                  Finnish Spitz   184
# 185                  Cesky Terrier   185
# 186              American Foxhound   186
# 187            Bergamasco Sheepdog   187
# 188               English Foxhound   188
# 189                        Harrier   189
# 190                        Chinook   190
# 191            Norwegian Lundehund   191
# 192                            NaN   192
#
# [192 rows x 2 columns]

# %%
top_breeds_df = top_breeds_df.rename(index=str, columns={"Breed": "primary breed"})
top_breeds_df.head()
# Out:
#          primary breed  Rank
# 1   Labrador Retriever     1
# 2  German Shepherd Dog     2
# 3     Golden Retriever     3
# 4       French Bulldog     4
# 5              Bulldog     5

# %%
top_breeds_list = top_breeds_df['primary breed'].tolist()

# %%
top_breeds_verified_on_petfinder = []
top_breeds_not_on_petfinder = []
for breed in top_breeds_list:
    if breed in PetFinder_DogBreeds:
        top_breeds_verified_on_petfinder.append(breed)
    else:
        top_breeds_not_on_petfinder.append(breed)

# %%
def saveList(myList,filename):
    # the filename should mention the extension 'npy'
    np.save(filename,myList)
    print("Saved successfully!")

# %%
def loadList(filename):
    # the filename should mention the extension 'npy'
    tempNumpyArray=np.load(filename)
    return tempNumpyArray.tolist()

# %%
saveList(top_breeds_verified_on_petfinder,"top_breeds_verified_on_petfinder.npy")

saveList(top_breeds_not_on_petfinder,"top_breeds_not_on_petfinder.npy")
# Out:
# Saved successfully!
# Saved successfully!

# %%
top_breeds_df.to_excel(r'altered_top_breeds_excel.xlsx')

# %%
top_breeds_df
# Out:
#                      primary breed  Rank
# 1               Labrador Retriever     1
# 2              German Shepherd Dog     2
# 3                 Golden Retriever     3
# 4                   French Bulldog     4
# 5                          Bulldog     5
# 6                           Beagle     6
# 7                           Poodle     7
# 8                       Rottweiler     8
# 9       German Shorthaired Pointer     9
# 10               Yorkshire Terrier    10
# 11                           Boxer    11
# 12                       Dachshund    12
# 13            Pembroke Welsh Corgi    13
# 14                  Siberian Husky    14
# 15             Australian Shepherd    15
# 16                      Great Dane    16
# 17               Doberman Pinscher    17
# 18   Cavalier King Charles Spaniel    18
# 19             Miniature Schnauzer    19
# 20                        Shih Tzu    20
# 21                  Boston Terrier    21
# 22            Bernese Mountain Dog    22
# 23                      Pomeranian    23
# 24                        Havanese    24
# 25     Shetland Sheepdog / Sheltie    25
# 26                        Brittany    26
# 27        English Springer Spaniel    27
# 28                             Pug    28
# 29                         Mastiff    29
# 30                  Cocker Spaniel    30
# ..                             ...   ...
# 163                         Kuvasz   163
# 164               Sealyham Terrier   164
# 165               Norwegian Buhund   165
# 166      Spaniels (American Water)   166
# 167              Wirehaired Vizsla   167
# 168                        Lowchen   168
# 169               Swedish Vallhund   169
# 170        Polish Lowland Sheepdog   170
# 171                    Plott Hound   171
# 172                  Pharaoh Hound   172
# 173                       Komondor   173
# 174          Glen of Imaal Terrier   174
# 175     American English Coonhound   175
# 176         Dandie Dinmont Terrier   176
# 177   Grand Basset Griffon Vendeen   177
# 178                   Skye Terrier   178
# 179                     Canaan Dog   179
# 180                 Sussex Spaniel   180
# 181              Pyrenean Shepherd   181
# 182                     Otterhound   182
# 183              Cirneco dell'Etna   183
# 184                  Finnish Spitz   184
# 185                  Cesky Terrier   185
# 186              American Foxhound   186
# 187            Bergamasco Sheepdog   187
# 188               English Foxhound   188
# 189                        Harrier   189
# 190                        Chinook   190
# 191            Norwegian Lundehund   191
# 192                            NaN   192
#
# [192 rows x 2 columns]

# %%
credentials = {
  'grant_type': 'client_credentials',
  'client_id': {CLIENTID},
  'client_secret': {CLIENTSECRET}
}

token_response = requests.post('https://api.petfinder.com/v2/oauth2/token', data=credentials)
access_token = token_response.json()['access_token']

data_auth = {
    'Authorization': f'Bearer {access_token}',
}

startTime = datetime.now()

# time to check start of access token 
print(startTime)
# Out:
# 2019-10-29 15:34:30.844205

# %%
top_breeds_verified_on_petfinder=loadList("top_breeds_verified_on_petfinder.npy")

# %%
top_breeds_verified_on_petfinder[0]
# Out:
# 'Labrador Retriever'

# %%
best_cities_df = pd.read_csv("web_scraping/best_cities.csv", names=['Rank','City','Total Score','Pet Budget Rank','Pet Health and Wellness Rank','Outdoor Pet Friendliness Rank'], header=-1)
best_cities_df.head()
# Out:
#    Rank            City  Total Score  Pet Budget Rank  \
# 0     1  Scottsdale, AZ        58.89               80
# 1     2     Orlando, FL        58.29                7
# 2     3       Tampa, FL        57.61               10
# 3     4      Austin, TX        56.17               31
# 4     5     Phoenix, AZ        55.89               26
#
#    Pet Health and Wellness Rank  Outdoor Pet Friendliness Rank
# 0                             1                              6
# 1                             4                             51
# 2                            17                             13
# 3                             2                             54
# 4                            16                             15

# %%
best_cities_df[['city','state']] = best_cities_df.City.str.split(',', expand=True)

# %%
best_cities_list = best_cities_df['city'].tolist()

# %%
best_cities_states_list = best_cities_df['state'].tolist()

# %%
best_cities_list[:5]
# Out:
# ['Scottsdale', 'Orlando', 'Tampa', 'Austin', 'Phoenix']

# %%
best_cities_states_list = [x.strip(' ') for x in best_cities_states_list]
best_cities_states_list[:5]
# Out:
# ['AZ', 'FL', 'FL', 'TX', 'AZ']

# %%
tupled_location = list(zip(best_cities_states_list, best_cities_list))

# %%
tupled_location[:10]
# Out:
# [('AZ', 'Scottsdale'),
#  ('FL', 'Orlando'),
#  ('FL', 'Tampa'),
#  ('TX', 'Austin'),
#  ('AZ', 'Phoenix'),
#  ('NV', 'Las Vegas'),
#  ('GA', 'Atlanta'),
#  ('MO', 'St. Louis'),
#  ('WA', 'Seattle'),
#  ('OR', 'Portland')]

# %%
print([i[1] for i in tupled_location][0])
# Out:
# Scottsdale

# %%
top_breeds_verified_on_petfinder[:5]
# Out:
# ['Labrador Retriever',
#  'German Shepherd Dog',
#  'Golden Retriever',
#  'French Bulldog',
#  'Beagle']

# %%
top_ten_breeds_verified_on_petfinder = top_breeds_verified_on_petfinder[:10]

# %%
top_ten_breeds_verified_on_petfinder
# Out:
# ['Labrador Retriever',
#  'German Shepherd Dog',
#  'Golden Retriever',
#  'French Bulldog',
#  'Beagle',
#  'Poodle',
#  'Rottweiler',
#  'German Shorthaired Pointer',
#  'Yorkshire Terrier',
#  'Boxer']

# %%
base_url = "https://api.petfinder.com/v2/animals?"
add_type = "&type="
add_breed = "&breed="
add_location = "&location="
end_url = "&page=1&limit=50"

# %%
combined_responses_df = pd.DataFrame(columns=['age', 'coat', 'gender', 'id', 'name', 'size', 'status',
       'declawed', 'house_trained', 'shots_current', 'spayed_neutered',
       'special_needs', 'mixed', 'primary_breed', 'secondary_breed', 'unknown_breed',
       'primary_color', 'secondary_color', 'tertiary_color', 'address.city',
       'address.state', 'cats', 'children', 'dogs','request_num'])

# %%
combined_responses_df
# Out:
# Empty DataFrame
# Columns: [age, coat, gender, id, name, size, status, declawed, house_trained, shots_current, spayed_neutered, special_needs, mixed, primary_breed, secondary_breed, unknown_breed, primary_color, secondary_color, tertiary_color, address.city, address.state, cats, children, dogs, request_num]
# Index: []
#
# [0 rows x 25 columns]

# %%
def Enquiry(lis1): 
    if len(lis1) == 0: 
        return 0
    else: 
        return 1

n = 0

# for k in range(0, len(tupled_location)):
for k in range(0, 10):
#     for breed in top_breeds_verified_on_petfinder:
    for breed in top_ten_breeds_verified_on_petfinder:
        target_url = base_url + add_type + "dog" + add_breed + breed + add_location + [i[0] for i in tupled_location][k] + "&" + [i[1] for i in tupled_location][k] + end_url
        n += 1
        time.sleep(5)
        data_response = requests.get(target_url, headers=data_auth)
        time.sleep(5)
        json_response = data_response.json() # this is a dictionary 
        response_df = pd.DataFrame.from_dict(json_response['animals'])
        if Enquiry(json_response['animals']): 
            print ("searching for " + breed + " in " + str([i[1] for i in tupled_location][k]))
            response_df = response_df.drop(columns=['_links','description','distance','organization_id','photos','published_at','species','status_changed_at','tags','type','url'])
            temp_df = json_normalize(response_df['attributes'])
            response_df = pd.concat([response_df,temp_df], axis=1)
            temp_df = json_normalize(response_df['breeds'])
            temp_df = temp_df.rename(columns={"primary": "primary_breed", "secondary": "secondary_breed", "unknown": "unknown_breed"})
            response_df = pd.concat([response_df,temp_df], axis=1)
            temp_df = json_normalize(response_df['colors'])
            temp_df = temp_df.rename(columns={"primary": "primary_color", "secondary": "secondary_color", "tertiary": "tertiary_color"})
            response_df = pd.concat([response_df,temp_df], axis=1)
            temp_df = json_normalize(response_df['contact'])
            response_df = pd.concat([response_df,temp_df], axis=1)
            temp_df = json_normalize(response_df['environment'])
            response_df = pd.concat([response_df,temp_df], axis=1)
            response_df = response_df.drop(columns=['attributes','breeds','colors','contact','address.address1','address.address2','address.country','address.postcode','email','phone','environment'])
            response_df['request_num'] = n
            combined_responses_df = combined_responses_df.append(response_df)
        else: 
            print(breed + " not found in " + str([i[1] for i in tupled_location][k]))

# %%
combined_responses_df.to_csv(r'top_10_cities_top_10_breeds.csv', index=False)

# %%
json_response
# Out:
# {'animals': [{'id': 46410712,
#    'organization_id': 'FL1290',
#    'url': 'https://www.petfinder.com/dog/lucy-46410712/fl/tampa/furever-yours-pet-rescue-and-placement-services-fl1290/?referrer_id=385b77c5-b2c7-4f66-b612-3b11db54788d',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Shetland Sheepdog / Sheltie',
#     'secondary': 'Labrador Retriever',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'Black', 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': 'Medium',
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': True, 'dogs': True, 'cats': True},
#    'tags': [],
#    'name': 'Lucy',
#    'description': 'Lucy is a 1 year old female, shelter/lab mix. She is petite about 20 pounds. She and her brother were...',
#    'photos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2019-10-29T00:51:13+0000',
#    'published_at': '2019-10-29T00:51:13+0000',
#    'distance': 47.3634,
#    'contact': {'email': 'fureveryourspetrescue@outlook.com',
#     'phone': '(813) 735-9376',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Tampa',
#      'state': 'FL',
#      'postcode': '33625',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/46410712'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl1290'}}},
#   {'id': 46410650,
#    'organization_id': 'FL1290',
#    'url': 'https://www.petfinder.com/dog/linus-46410650/fl/tampa/furever-yours-pet-rescue-and-placement-services-fl1290/?referrer_id=385b77c5-b2c7-4f66-b612-3b11db54788d',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Shetland Sheepdog / Sheltie',
#     'secondary': 'Labrador Retriever',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'Black',
#     'secondary': 'White / Cream',
#     'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Small',
#    'coat': 'Medium',
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': True, 'dogs': True, 'cats': True},
#    'tags': [],
#    'name': 'Linus',
#    'description': 'Linus is a 1 year old male, shelter/lab mix. He is petite about 15 pounds. He and his sister were...',
#    'photos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2019-10-29T00:42:55+0000',
#    'published_at': '2019-10-29T00:42:55+0000',
#    'distance': 47.3634,
#    'contact': {'email': 'fureveryourspetrescue@outlook.com',
#     'phone': '(813) 735-9376',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Tampa',
#      'state': 'FL',
#      'postcode': '33625',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/46410650'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl1290'}}},
#   {'id': 46408929,
#    'organization_id': 'FL275',
#    'url': 'https://www.petfinder.com/dog/luna-46408929/fl/orlando/orange-county-animal-services-fl275/?referrer_id=385b77c5-b2c7-4f66-b612-3b11db54788d',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Labrador Retriever',
#     'secondary': 'Redbone Coonhound',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'LUNA',
#    'description': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46408929/1/?bust=1572298240&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46408929/1/?bust=1572298240&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46408929/1/?bust=1572298240&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46408929/1/?bust=1572298240'}],
#    'status': 'adoptable',
#    'status_changed_at': '2019-10-28T21:25:36+0000',
#    'published_at': '2019-10-28T21:25:36+0000',
#    'distance': 69.0662,
#    'contact': {'email': 'AnimalServices@ocfl.net',
#     'phone': None,
#     'address': {'address1': '2769 Conroy Road',
#      'address2': None,
#      'city': 'Orlando',
#      'state': 'FL',
#      'postcode': '32839',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/46408929'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl275'}}},
#   {'id': 46406819,
#    'organization_id': 'FL1561',
#    'url': 'https://www.petfinder.com/dog/oreo-46406819/fl/deltona/metta-rescue-family-fl1561/?referrer_id=385b77c5-b2c7-4f66-b612-3b11db54788d',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Labrador Retriever',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'Black', 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': True, 'dogs': True, 'cats': True},
#    'tags': [],
#    'name': 'Oreo',
#    'description': 'Oreo is a fun, spunky girl who loves to play and makes friends with everyone she meets. Although she gets...',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46406819/1/?bust=1572288130&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46406819/1/?bust=1572288130&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46406819/1/?bust=1572288130&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46406819/1/?bust=1572288130'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46406819/3/?bust=1572288131&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46406819/3/?bust=1572288131&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46406819/3/?bust=1572288131&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46406819/3/?bust=1572288131'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46406819/2/?bust=1572288131&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46406819/2/?bust=1572288131&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46406819/2/?bust=1572288131&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46406819/2/?bust=1572288131'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46406819/4/?bust=1572288131&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46406819/4/?bust=1572288131&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46406819/4/?bust=1572288131&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46406819/4/?bust=1572288131'}],
#    'status': 'adopted',
#    'status_changed_at': '2019-10-28T18:37:08+0000',
#    'published_at': '2019-10-28T18:37:08+0000',
#    'distance': 80.0342,
#    'contact': {'email': 'info@mettarescuefamily.org',
#     'phone': None,
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Deltona',
#      'state': 'FL',
#      'postcode': '32738',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/46406819'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl1561'}}},
#   {'id': 46406064,
#    'organization_id': 'FL258',
#    'url': 'https://www.petfinder.com/dog/logan-46406064/fl/winter-haven/polk-county-animal-control-fl258/?referrer_id=385b77c5-b2c7-4f66-b612-3b11db54788d',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Labrador Retriever',
#     'secondary': 'Mixed Breed',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'LOGAN',
#    'description': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46406064/1/?bust=1572283807&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46406064/1/?bust=1572283807&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46406064/1/?bust=1572283807&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46406064/1/?bust=1572283807'}],
#    'status': 'adoptable',
#    'status_changed_at': '2019-10-28T17:25:03+0000',
#    'published_at': '2019-10-28T17:25:03+0000',
#    'distance': 68.7013,
#    'contact': {'email': 'animalrescue@polksheriff.org',
#     'phone': '(863) 577-1762',
#     'address': {'address1': '7115 De Castro Road',
#      'address2': None,
#      'city': 'Winter Haven',
#      'state': 'FL',
#      'postcode': '33880',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/46406064'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl258'}}},
#   {'id': 46405285,
#    'organization_id': 'FL668',
#    'url': 'https://www.petfinder.com/dog/andre-the-giant-46405285/fl/oviedo/save-a-life-pet-rescue-fl668/?referrer_id=385b77c5-b2c7-4f66-b612-3b11db54788d',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Beagle',
#     'secondary': 'Labrador Retriever',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': True, 'dogs': True, 'cats': True},
#    'tags': [],
#    'name': 'Andre the Giant',
#    'description': '***SIGN IN SHEET IS POSTED AT NOON***\n\nALL PETS ARE RESCUED FROM HIGH-KILL ANIMAL CONTROLS.  WE CANNOT GUARANTEE THE MIXED...',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46405285/1/?bust=1572279211&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46405285/1/?bust=1572279211&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46405285/1/?bust=1572279211&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46405285/1/?bust=1572279211'}],
#    'status': 'adoptable',
#    'status_changed_at': '2019-10-28T16:14:08+0000',
#    'published_at': '2019-10-28T16:14:08+0000',
#    'distance': 78.473,
#    'contact': {'email': 'Savealifepetres@aol.com',
#     'phone': '(407) 952-1037',
#     'address': {'address1': 'PO Box 623341',
#      'address2': None,
#      'city': 'Oviedo',
#      'state': 'FL',
#      'postcode': '32762',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/46405285'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl668'}}},
#   {'id': 46405265,
#    'organization_id': 'FL668',
#    'url': 'https://www.petfinder.com/dog/bo-peep-46405265/fl/oviedo/save-a-life-pet-rescue-fl668/?referrer_id=385b77c5-b2c7-4f66-b612-3b11db54788d',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Border Collie',
#     'secondary': 'Labrador Retriever',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': True, 'dogs': True, 'cats': True},
#    'tags': [],
#    'name': 'Bo peep',
#    'description': '***SIGN IN SHEET IS POSTED AT NOON***\n\nALL PETS ARE RESCUED FROM HIGH-KILL ANIMAL CONTROLS.  WE CANNOT GUARANTEE THE MIXED...',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46405265/1/?bust=1572278934&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46405265/1/?bust=1572278934&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46405265/1/?bust=1572278934&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46405265/1/?bust=1572278934'}],
#    'status': 'adoptable',
#    'status_changed_at': '2019-10-28T16:09:09+0000',
#    'published_at': '2019-10-28T16:09:09+0000',
#    'distance': 78.473,
#    'contact': {'email': 'Savealifepetres@aol.com',
#     'phone': '(407) 952-1037',
#     'address': {'address1': 'PO Box 623341',
#      'address2': None,
#      'city': 'Oviedo',
#      'state': 'FL',
#      'postcode': '32762',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/46405265'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl668'}}},
#   {'id': 46403313,
#    'organization_id': 'FL128',
#    'url': 'https://www.petfinder.com/dog/nikki-46403313/fl/gainesville/humane-society-of-north-central-florida-fl128/?referrer_id=385b77c5-b2c7-4f66-b612-3b11db54788d',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Cattle Dog',
#     'secondary': 'Labrador Retriever',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Nikki',
#    'description': None,
#    'photos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2019-10-28T06:31:02+0000',
#    'published_at': '2019-10-28T06:31:02+0000',
#    'distance': 66.6689,
#    'contact': {'email': 'info@humanesocietyncfl.org',
#     'phone': '(352) 373-5855',
#     'address': {'address1': '4205 NW 6th Street',
#      'address2': None,
#      'city': 'Gainesville',
#      'state': 'FL',
#      'postcode': '32609',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/46403313'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl128'}}},
#   {'id': 46401079,
#    'organization_id': 'FL275',
#    'url': 'https://www.petfinder.com/dog/onyx-46401079/fl/orlando/orange-county-animal-services-fl275/?referrer_id=385b77c5-b2c7-4f66-b612-3b11db54788d',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Labrador Retriever',
#     'secondary': 'Mixed Breed',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Female',
#    'size': 'Large',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'ONYX',
#    'description': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46401079/1/?bust=1572276599&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46401079/1/?bust=1572276599&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46401079/1/?bust=1572276599&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46401079/1/?bust=1572276599'}],
#    'status': 'adoptable',
#    'status_changed_at': '2019-10-27T22:23:00+0000',
#    'published_at': '2019-10-27T22:23:00+0000',
#    'distance': 69.0662,
#    'contact': {'email': 'AnimalServices@ocfl.net',
#     'phone': None,
#     'address': {'address1': '2769 Conroy Road',
#      'address2': None,
#      'city': 'Orlando',
#      'state': 'FL',
#      'postcode': '32839',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/46401079'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl275'}}},
#   {'id': 46400871,
#    'organization_id': 'FL1290',
#    'url': 'https://www.petfinder.com/dog/ivy-46400871/fl/tampa/furever-yours-pet-rescue-and-placement-services-fl1290/?referrer_id=385b77c5-b2c7-4f66-b612-3b11db54788d',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Labrador Retriever',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Black',
#     'secondary': 'White / Cream',
#     'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': 'Medium',
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': True, 'dogs': True, 'cats': True},
#    'tags': [],
#    'name': 'Ivy',
#    'description': 'Courtesy post: One of. our previously adopted dogs needs to be re-homed due to work schedule change. We are helping...',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400871/1/?bust=1572212884&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400871/1/?bust=1572212884&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400871/1/?bust=1572212884&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400871/1/?bust=1572212884'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400871/2/?bust=1572212892&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400871/2/?bust=1572212892&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400871/2/?bust=1572212892&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400871/2/?bust=1572212892'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400871/3/?bust=1572212896&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400871/3/?bust=1572212896&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400871/3/?bust=1572212896&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400871/3/?bust=1572212896'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400871/4/?bust=1572212932&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400871/4/?bust=1572212932&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400871/4/?bust=1572212932&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400871/4/?bust=1572212932'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400871/5/?bust=1572212937&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400871/5/?bust=1572212937&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400871/5/?bust=1572212937&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400871/5/?bust=1572212937'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400871/6/?bust=1572212940&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400871/6/?bust=1572212940&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400871/6/?bust=1572212940&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400871/6/?bust=1572212940'}],
#    'status': 'adoptable',
#    'status_changed_at': '2019-10-27T21:57:46+0000',
#    'published_at': '2019-10-27T21:57:46+0000',
#    'distance': 47.3634,
#    'contact': {'email': 'fureveryourspetrescue@outlook.com',
#     'phone': '(813) 735-9376',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Tampa',
#      'state': 'FL',
#      'postcode': '33625',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/46400871'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl1290'}}},
#   {'id': 46400371,
#    'organization_id': 'FL189',
#    'url': 'https://www.petfinder.com/dog/pink-the-shipyard-lab-mix-puppy-46400371/fl/sanford/pet-rescue-by-judy-fl189/?referrer_id=385b77c5-b2c7-4f66-b612-3b11db54788d',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Labrador Retriever',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Large',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': True, 'dogs': True, 'cats': True},
#    'tags': [],
#    'name': 'Pink the Shipyard Lab Mix Puppy',
#    'description': 'You can fill out an adoption application online on our official website.Pink and her sibling Fanny were rescued at a...',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400371/1/?bust=1572210338&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400371/1/?bust=1572210338&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400371/1/?bust=1572210338&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400371/1/?bust=1572210338'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400371/3/?bust=1572210337&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400371/3/?bust=1572210337&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400371/3/?bust=1572210337&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400371/3/?bust=1572210337'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400371/2/?bust=1572210338&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400371/2/?bust=1572210338&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400371/2/?bust=1572210338&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46400371/2/?bust=1572210338'}],
#    'status': 'adopted',
#    'status_changed_at': '2019-10-27T21:00:34+0000',
#    'published_at': '2019-10-27T21:00:34+0000',
#    'distance': 73.8518,
#    'contact': {'email': 'info@petrescuebyjudy.com',
#     'phone': '(407) 302-4497',
#     'address': {'address1': '401 South Laurel Avenue',
#      'address2': None,
#      'city': 'Sanford',
#      'state': 'FL',
#      'postcode': '32771',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/46400371'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl189'}}},
#   {'id': 46396470,
#    'organization_id': 'FL128',
#    'url': 'https://www.petfinder.com/dog/eve-46396470/fl/gainesville/humane-society-of-north-central-florida-fl128/?referrer_id=385b77c5-b2c7-4f66-b612-3b11db54788d',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Labrador Retriever',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Eve',
#    'description': None,
#    'photos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2019-10-27T06:31:12+0000',
#    'published_at': '2019-10-27T06:31:12+0000',
#    'distance': 66.6689,
#    'contact': {'email': 'info@humanesocietyncfl.org',
#     'phone': '(352) 373-5855',
#     'address': {'address1': '4205 NW 6th Street',
#      'address2': None,
#      'city': 'Gainesville',
#      'state': 'FL',
#      'postcode': '32609',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/46396470'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl128'}}},
#   {'id': 46396312,
#    'organization_id': 'FL159',
#    'url': 'https://www.petfinder.com/dog/merle-46396312/fl/sarasota/humane-society-of-sarasota-county-inc-fl159/?referrer_id=385b77c5-b2c7-4f66-b612-3b11db54788d',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Labrador Retriever',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Merle',
#    'description': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46396312/1/?bust=1572158132&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46396312/1/?bust=1572158132&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46396312/1/?bust=1572158132&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46396312/1/?bust=1572158132'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46396312/2/?bust=1572158133&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46396312/2/?bust=1572158133&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46396312/2/?bust=1572158133&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46396312/2/?bust=1572158133'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46396312/3/?bust=1572158134&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46396312/3/?bust=1572158134&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46396312/3/?bust=1572158134&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46396312/3/?bust=1572158134'}],
#    'status': 'adoptable',
#    'status_changed_at': '2019-10-27T06:30:29+0000',
#    'published_at': '2019-10-27T06:30:29+0000',
#    'distance': 97.7732,
#    'contact': {'email': 'tstoddard@hssc.org',
#     'phone': '(941) 955-4131',
#     'address': {'address1': '2331 15th Street',
#      'address2': None,
#      'city': 'Sarasota',
#      'state': 'FL',
#      'postcode': '34237',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/46396312'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl159'}}},
#   {'id': 46390975,
#    'organization_id': 'FL164',
#    'url': 'https://www.petfinder.com/dog/tilda-46390975/fl/gainesville/alachua-county-animal-services-fl164/?referrer_id=385b77c5-b2c7-4f66-b612-3b11db54788d',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Labrador Retriever',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Female',
#    'size': 'Large',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'TILDA',
#    'description': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46390975/1/?bust=1572107050&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46390975/1/?bust=1572107050&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46390975/1/?bust=1572107050&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46390975/1/?bust=1572107050'}],
#    'status': 'adoptable',
#    'status_changed_at': '2019-10-26T16:18:56+0000',
#    'published_at': '2019-10-26T16:18:56+0000',
#    'distance': 66.6689,
#    'contact': {'email': 'sclontz@alachuacounty.us',
#     'phone': '352-264-6870',
#     'address': {'address1': '3400 NE 53rd Avenue',
#      'address2': None,
#      'city': 'Gainesville',
#      'state': 'FL',
#      'postcode': '32609',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/46390975'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl164'}}},
#   {'id': 46389891,
#    'organization_id': 'FL367',
#    'url': 'https://www.petfinder.com/dog/dara-46389891/fl/largo/pinellas-county-animal-services-fl367/?referrer_id=385b77c5-b2c7-4f66-b612-3b11db54788d',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Labrador Retriever',
#     'secondary': 'American Staffordshire Terrier',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': True, 'dogs': True, 'cats': True},
#    'tags': [],
#    'name': 'Dara',
#    'description': 'Dara is beautiful and smart, what a combination! She is also a happy girl and likes to play with toys....',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46389891/2/?bust=1572279089&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46389891/2/?bust=1572279089&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46389891/2/?bust=1572279089&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46389891/2/?bust=1572279089'}],
#    'status': 'adoptable',
#    'status_changed_at': '2019-10-26T14:06:18+0000',
#    'published_at': '2019-10-26T14:06:18+0000',
#    'distance': 63.2783,
#    'contact': {'email': 'cmiller@pinellascounty.org',
#     'phone': '(727)582-2600',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Largo',
#      'state': 'FL',
#      'postcode': '33774',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/46389891'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl367'}}},
#   {'id': 46388166,
#    'organization_id': 'FL128',
#    'url': 'https://www.petfinder.com/dog/hermione-46388166/fl/gainesville/humane-society-of-north-central-florida-fl128/?referrer_id=385b77c5-b2c7-4f66-b612-3b11db54788d',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Labrador Retriever',
#     'secondary': 'Treeing Walker Coonhound',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Hermione',
#    'description': None,
#    'photos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2019-10-26T06:31:54+0000',
#    'published_at': '2019-10-26T06:31:54+0000',
#    'distance': 66.6689,
#    'contact': {'email': 'info@humanesocietyncfl.org',
#     'phone': '(352) 373-5855',
#     'address': {'address1': '4205 NW 6th Street',
#      'address2': None,
#      'city': 'Gainesville',
#      'state': 'FL',
#      'postcode': '32609',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/46388166'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl128'}}},
#   {'id': 46384967,
#    'organization_id': 'FL312',
#    'url': 'https://www.petfinder.com/dog/ebony-46384967/fl/saint-cloud/osceola-county-animal-services-fl312/?referrer_id=385b77c5-b2c7-4f66-b612-3b11db54788d',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Labrador Retriever',
#     'secondary': 'Mixed Breed',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Female',
#    'size': 'Large',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'EBONY',
#    'description': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46384967/1/?bust=1572042137&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46384967/1/?bust=1572042137&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46384967/1/?bust=1572042137&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46384967/1/?bust=1572042137'}],
#    'status': 'adoptable',
#    'status_changed_at': '2019-10-25T22:17:02+0000',
#    'published_at': '2019-10-25T22:17:02+0000',
#    'distance': 82.3177,
#    'contact': {'email': 'petinquiries@osceola.org',
#     'phone': None,
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Saint Cloud',
#      'state': 'FL',
#      'postcode': '34769',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/46384967'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl312'}}},
#   {'id': 46383814,
#    'organization_id': 'FL275',
#    'url': 'https://www.petfinder.com/dog/kaos-46383814/fl/orlando/orange-county-animal-services-fl275/?referrer_id=385b77c5-b2c7-4f66-b612-3b11db54788d',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Labrador Retriever',
#     'secondary': 'Mixed Breed',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Large',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'KAOS',
#    'description': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46383814/1/?bust=1572272955&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46383814/1/?bust=1572272955&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46383814/1/?bust=1572272955&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46383814/1/?bust=1572272955'}],
#    'status': 'adoptable',
#    'status_changed_at': '2019-10-25T20:16:30+0000',
#    'published_at': '2019-10-25T20:16:30+0000',
#    'distance': 69.0662,
#    'contact': {'email': 'AnimalServices@ocfl.net',
#     'phone': None,
#     'address': {'address1': '2769 Conroy Road',
#      'address2': None,
#      'city': 'Orlando',
#      'state': 'FL',
#      'postcode': '32839',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/46383814'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl275'}}},
#   {'id': 46382004,
#    'organization_id': 'FL164',
#    'url': 'https://www.petfinder.com/dog/teah-46382004/fl/gainesville/alachua-county-animal-services-fl164/?referrer_id=385b77c5-b2c7-4f66-b612-3b11db54788d',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Labrador Retriever',
#     'secondary': 'Mixed Breed',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'TEAH',
#    'description': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46382004/1/?bust=1572027648&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46382004/1/?bust=1572027648&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46382004/1/?bust=1572027648&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46382004/1/?bust=1572027648'}],
#    'status': 'adoptable',
#    'status_changed_at': '2019-10-25T18:15:42+0000',
#    'published_at': '2019-10-25T18:15:42+0000',
#    'distance': 66.6689,
#    'contact': {'email': 'sclontz@alachuacounty.us',
#     'phone': '352-264-6870',
#     'address': {'address1': '3400 NE 53rd Avenue',
#      'address2': None,
#      'city': 'Gainesville',
#      'state': 'FL',
#      'postcode': '32609',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/46382004'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl164'}}},
#   {'id': 46380229,
#    'organization_id': 'FL367',
#    'url': 'https://www.petfinder.com/dog/dinky-46380229/fl/largo/pinellas-county-animal-services-fl367/?referrer_id=385b77c5-b2c7-4f66-b612-3b11db54788d',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Labrador Retriever',
#     'secondary': 'Mixed Breed',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': True, 'dogs': True, 'cats': True},
#    'tags': [],
#    'name': 'Dinky',
#    'description': 'He&amp;#39;s tall and 57 pounds. Dinky? Maybe &amp;#34;Huggie&amp;#34; would more appropriate because this pal just wants to wrap his paws...',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46380229/1/?bust=1572217907&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46380229/1/?bust=1572217907&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46380229/1/?bust=1572217907&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/46380229/1/?bust=1572217907'}],
#    'status': 'adoptable',
#    'status_changed_at': '2019-10-25T16:06:31+0000',
#    'published_at': '2019-10-25T16:06:31+0000',
#    'distance': 63.2783,
#    'contact': {'email': 'cmiller@pinellascounty.org',
#     'phone': '(727)582-2600',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Largo',
#      'state': 'FL',
#      'postcode': '33774',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/46380229'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl367'}}}],
#  'pagination': {'count_per_page': 20,
#   'total_count': 22488,
#   'current_page': 1,
#   'total_pages': 1125,
#   '_links': {'next': {'href': '/v2/animals?breed=Labrador%20Retriever&limit=20&location=florida&orlando=&page=2&type=dog'}}}}
